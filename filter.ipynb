# %%
import pandas as pd

# %%
df = pd.read_csv(r'test\test_googlecrawer2\(silica nanoparticles) AND (Cytotoxicity)\logfile_09-14-2025.csv')
df
# Out:
#      Unnamed: 0                                              title  \
# 0             1  silica nanoparticles-induced cytotoxicity and ...
# 1             2  vdac1 protein regulation of oxidative damage a...
# 2             3  curcumin-loaded mesoporous silica nanoparticle...
# 3             4  selenium-incorporated mesoporous silica nanopa...
# 4             5  toxicity evaluation of silica nanoparticles fo...
# ..          ...                                                ...
# 561         596  leveraging senescent cancer cell membrane to p...
# 562         597  html zeolitic imidazole frameworksilica nanoco...
# 563         598  inorganic nanoparticle-based treatment approac...
# 564         599  pharmacokinetics of nanoparticles: current kno...
# 565         600  organotin ivdecorated graphene quantum dots as...
#
#          author                                    journal          year  \
# 0      peivandi                         scientific reports          2024
# ...

# %%
df[df['year'] >= '2022']
# Out:
#      Unnamed: 0                                              title  \
# 0             1  silica nanoparticles-induced cytotoxicity and ...
# 1             2  vdac1 protein regulation of oxidative damage a...
# 2             3  curcumin-loaded mesoporous silica nanoparticle...
# 3             4  selenium-incorporated mesoporous silica nanopa...
# 4             5  toxicity evaluation of silica nanoparticles fo...
# ..          ...                                                ...
# 561         596  leveraging senescent cancer cell membrane to p...
# 562         597  html zeolitic imidazole frameworksilica nanoco...
# 563         598  inorganic nanoparticle-based treatment approac...
# 564         599  pharmacokinetics of nanoparticles: current kno...
# 565         600  organotin ivdecorated graphene quantum dots as...
#
#          author                                    journal          year  \
# 0      peivandi                         scientific reports          2024
# ...

# %%
df[~df['filename'].str.contains('cancer')]
# Out:
#      Unnamed: 0                                              title  \
# 0             1  silica nanoparticles-induced cytotoxicity and ...
# 1             2  vdac1 protein regulation of oxidative damage a...
# 2             3  curcumin-loaded mesoporous silica nanoparticle...
# 3             4  selenium-incorporated mesoporous silica nanopa...
# 4             5  toxicity evaluation of silica nanoparticles fo...
# ..          ...                                                ...
# 557         592      emerging biomaterials for tumor immunotherapy
# 559         594  an esterase-activatable nanoprodrug mitigates ...
# 560         595  emerging nanoparticle platforms for cpg oligon...
# 564         599  pharmacokinetics of nanoparticles: current kno...
# 565         600  organotin ivdecorated graphene quantum dots as...
#
#          author                                    journal       year  \
# 0      peivandi                         scientific reports       2024
# ...

# %%
df[~df['filename'].str.contains('cancer')].to_csv('logfile_09-14-2025_filtered.csv',encoding='utf_8_sig',index=0)
